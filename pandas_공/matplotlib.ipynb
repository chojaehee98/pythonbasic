# %% [markdown]
# matplotlib :  자료를 차트, 플롯으로 시각화하는 패키징

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline # 주피터 내부에 그림을 표시하도록 지정 해줘야함
# Out:
# UsageError: unrecognized arguments: # 주피터 내부에 그림을 표시하도록 지정 해줘야함

# %%
plt.title('plot')
plt.plot([1,4,9,16])     # y 값
plt.show()

# %% [markdown]
# # title() 는 플롯의 제목을 의미한다
# # show()는 플롯의 그림을 보여준다
# # plot() x,y와 값을 나타

# %%
plt.title('x ticks')  
plt.plot([10,20,30,40],[1,4,9,16])   # x,y값
plt.show()

# %% [markdown]
# 제목을 한글로 하니 오류가 뜬다

# %%
plt.title('한글 제목')
plt.plot([10,20,30,40],[1,4,9,16])
plt.show()
# Out:
# C:\Users\jaehee\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jaehee\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jaehee\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jaehee\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 시스템 폰트 경로 리스트
font_list = mpl.font_manager.findSystemFonts()
print(font_list)
# Out:
# ['C:\\Windows\\Fonts\\MM.TTF', 'C:\\Windows\\Fonts\\OCRAEXT.TTF', 'C:\\Windows\\Fonts\\HATTEN.TTF', 'C:\\Windows\\Fonts\\BOOKOSBI.TTF', 'C:\\Windows\\Fonts\\trebuc.ttf', 'C:\\Windows\\Fonts\\symbol.ttf', 'C:\\Windows\\Fonts\\TCB_____.TTF', 'C:\\Windows\\Fonts\\CHILLER.TTF', 'C:\\Windows\\Fonts\\H2SA1M.TTF', 'C:\\Windows\\Fonts\\BOD_BLAI.TTF', 'C:\\Windows\\Fonts\\BROADW.TTF', 'C:\\Windows\\Fonts\\HANBatang.ttf', 'C:\\Windows\\Fonts\\ITCEDSCR.TTF', 'C:\\Windows\\Fonts\\georgiab.ttf', 'C:\\Windows\\Fonts\\COPRGTL.TTF', 'C:\\Windows\\Fonts\\corbelz.ttf', 'C:\\Windows\\Fonts\\ntailu.ttf', 'C:\\Windows\\Fonts\\IMPRISHA.TTF', 'C:\\Windows\\Fonts\\ARLRDBD.TTF', 'C:\\Windows\\Fonts\\GOTHICB.TTF', 'C:\\Windows\\Fonts\\PALSCRI.TTF', 'C:\\Windows\\Fonts\\cambria.ttc', 'C:\\Windows\\Fonts\\ARIALNBI.TTF', 'C:\\Windows\\Fonts\\SNAP____.TTF', 'C:\\Windows\\Fonts\\LSANS.TTF', 'C:\\Windows\\Fonts\\MN.TTF', 'C:\\Windows\\Fonts\\CASTELAR.TTF', 'C:\\Windows\\Fonts\\ELEPHNTI.TTF', 'C:\\Windows\\Fonts\\tr
# ...

# %%
# 폰트 설정하기
prop = mpl.font_manager.FontProperties(fname='원하는 폰트 경로')
plt.rcParams['font.family'] = prop.get_family()

# %%
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['./fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)
# Out:
# NanumMyeongjoOTF
# Noto Sans KR
# NanumSquareOTF
# NanumGothicOTF
# NanumSquare Neo Regular
# NanumMyeongjo
# NanumSquareRound
# NanumGothicOTF Eco
# D2Coding
# NanumMyeongjo Eco
# NanumMyeongjoOTF Eco
# NanumSquareRoundOTF
# NanumBarunGothicOTF
# NanumBarunpenOTF
# NanumSquareRound
# NanumGothic
# NanumSquare Neo OTF ExtraBold
# NanumBarunGothicOTF YetHangul
# Nanum Pen Script OTF
# NanumBarunGothic
# NanumGothic Eco
# NanumGothicOTF Eco
# Nanum Brush Script
# NanumBarunpen
# NanumSquare
# Noto Sans KR
# NanumSquare Neo Heavy
# NanumBarunGothic YetHangul
# NanumBarunGothicOTF
# NanumSquareOTF_ac
# NanumGothicOTF
# D2Coding ligature
# NanumSquareRoundOTF
# Nanum Brush Script OTF
# NanumBarunGothicOTF
# NanumSquare Neo ExtraBold
# Noto Sans KR
# NanumSquareOTF
# NanumSquareRound
# Noto Sans KR
# NanumBarunGothicOTF
# NanumGothic
# NanumSquareOTF
# NanumMyeongjo Eco
# D2Coding ligature
# NanumBarunpen
# NanumSquare Neo OTF Bold
# NanumSquare_ac
# NanumMyeongjoOTF
# NanumSquare
# ...

# %%
# %pwd
# Out:
# 'C:\\python\\pandas_공'

# %%
# %cd c:\\python
# Out:
# c:\python

# %%
# Set font family globally
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# ['Noto Sans KR']

# %%
plt.title('한글')
plt.plot(range(1,5))
plt.show()

# %% [markdown]
# 한글 폰트 사용 : 기본 폰츠 설정

# %%
global_font = {'family':'NanumGothic','size':12,'weight':'bold'}

#폰트 설정
mpl.rc('font',**global_font)

# %%
plt.title('한글 제목')
plt.plot([10,20,30,40],[1,4,9,16])
plt.xlabel('엑스축 레이블')
plt.ylabel('와이축 레이블')
plt.show()

# %%
title_font = {"family":"NanumMyeongjo",
              "size":24,
              "color":"black"}
xlabel_font = {"family":"NanumBarunpen",
               "size":18,
               "weight":"bold",
               "color":"darkred"}
ylabel_font = {"family":"NanumBarunGothic",
               "size":12,
               "weight":"light",
               "color":"blue"}
plt.title("한글",fontdict=title_font)
plt.plot([10,20,30,40],[1,4,9,16])
plt.xlabel("엑스축 레이블",fontdict=xlabel_font)
plt.ylabel("와이축 레이블",fontdict=ylabel_font)
plt.show()

# %%
# 유니코드에서 음수 부호 설정
mpl.rc('axes',unicode_minus=False)

# %% [markdown]
# style 설정

# %%
plt.title('default 스타일의 plot ')
plt.plot([10,20,30,40],[1,4,9,16])
plt.show()

# %%
plt.title("'rs--' 스타일의 plot  ")
plt.plot([10,20,30,40],[1,4,9,16], 'rp--')   # 'rp--'는 줄의 모양을 보여줌
plt.show()

# %% [markdown]
# ### 색상, 마커, 선종류의 순서로 지정한다
#
# #### 직접 RGB코드로도 가능하다.
#
# #### https://matplotlib.org/2.0.2/examples/color/named_colors.html 여기 사이트로 들어가면 색깔의 약자 보여줌
#
# #### 데이터의 위치를 나타내는 기호를 마커라 한다.
# https://matplotlib.org/2.0.2/api/markers_api.html?highlight=marker#module-matplotlib.markers
#
# #### 선 종류
# https://matplotlib.org/2.0.2/api/lines_api.html?highlight=line%20style#matplotlib.lines.Line2D.set_linestyle

# %%
plt.plot([10,20,30,40],[1,4,9,16],c='b',
         lw=5, ls='--', marker='o', ms =15,mec='g',mew=5, mfc='r')
plt.title('스타일 적용 예')
plt.show()

# %%
plt.title('x축,y축 범위 설정')
plt.plot([10,20,30,40],[1,4,9,16],
         c='b', lw=5, ls='--', marker='o', ms=15, mec='g', mew=5, mfc='r')
plt.xlim(0,50)
plt.ylim(-10,30)
plt.show()

# %% [markdown]
# ### 틱 설정하기
# ##### 틱의 위치나 틱 라벨은 맷플롯리브가 자동으로
# ##### 정해주지만 만약 수동으로 설정하고 싶다면
# ##### xticks() 이나 yticks()를 사용합니다.
# https://matplotlib.org/3.1.1/tutorials/text/mathtext.html

# %%
import numpy as np
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title('x축과 y축의 tick label 설정')
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
plt.yticks([-1, 0, +1])
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title('TeX, 문자열로 tick label 설정')
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, +1], ['Low', 'Zero', 'High'])
plt.show()

# %%
t = np.arange(0., 5., 0.2)
plt.title('라인 플롯에서 여러개의 선 그리기')
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2*t**3,'g^-')
plt.show()

# %%
plt.title("복수의 plot 명령을 한 그림에서 표현")
style1 = {"c":"b", 'lw' : 5, 'ls' : '--', 'marker' : 'o', 'ms' : 15, 'mec' : 'g', 'mew' : 5, 'mfc' : 'r'}
style2 = {"c":"k", 'lw' : 3, 'ls' : ':', 'marker' : 's', 'ms' : 10, 'mec' : 'm', 'mew' : 5, 'mfc' : 'c'}
plt.plot([1, 4, 9, 16], **style1)
plt.plot([9, 16, 4, 1], **style2)
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title('legend를 표시한 플롯')
plt.plot(X, C, ls='--', label='cosine')
plt.plot(X, S, ls=':', label='sine')
plt.legend(loc=2) # upper left
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, label='cosine')
plt.xlabel('time')
plt.ylabel('amplitude')
plt.title('Cosine Plot')
plt.show()

# %%
X = np.arange(32,100)
Y = (X-32)*5/9
plt.title("섭씨 온도와 화씨 온도")
plt.plot(X,Y, 'r-.')   
plt.xlabel('화씨 온도')
plt.ylabel('섭씨 온도')
plt.show()

# %% [markdown]
# ## Figure
# #### x-y 좌표의 그래프로 표시 Figure는 하나 이상의 Axes를 가진다.
# #### pyplot.subplots()을 사용하는 것 그 후 Axes.plot()를 활용하여 Axes에 데이터를 그린다

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3,4],[1,4,2,3])

# %% [markdown]
# Figure는 전체 그림(그래프)을 의미하는 객체이다.
# Axes, 특수 Artist그룹, 중첩된 subfigures까지 포함할 수 있다.
# 가장 쉬운 방법 : Figure 객체를 생성하는 방법

# %%
fig = plt.figure()     # empth figure with no axes
fig, ax = plt.subplots()    #figure with single axes
fig, axs = plt.subplots(2,2)  # 2x2 grid of axes

# %% [markdown]
# Figure 객체를 생성하려면 figure()을 사용하여 그 반환값으로
# Figure 객체를 얻어야 한다. 그러나 plot() 명령만 실행해도 자동으로 생성되기 때문에
# figure()를 잘 사용하지 않습니다.

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10,2))
plt.title('figure size : (10,2)')
plt.plot(np.random.randn(100))
plt.show()

# %%
f1 = plt.figure(1)
plt.title('현재의 Figure 객체')
plt.plot([1,2,3,4], 'ro:')

f2 = plt.gcf()
print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(640x480) 2296565234368
# Figure(640x480) 2296565234368

# %%
ax1 = plt.subplot(2,1,1)  # 윗부분에 그릴 플롯 명령 실행

# %%
ax2 = plt.subplot(2,1,2)  # 아랫부분에 그릴 플롯 명령 실행

# %%
# tight_layout() 명령을 실행하면 플롯 간의 간격을 자동으로 맞춰줍니다.

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2,1,1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(2,1,2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()
plt.show()

# %%
# 2x2 형태의 네 개의 플롯

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title('axes 1')

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title('axes 2')

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title('axes 3')

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title('axes 4')

plt.tight_layout()
plt.show()

# %% [markdown]
# subplot()와 subplots()는 다름

# %%
fig, axes = plt.subplots(2,2)

np.random.seed(0)
axes[0,0].plot(np.random.rand(5))
axes[0,0].set_title('axes 1')
axes[0,1].plot(np.random.rand(5))
axes[0,1].set_title('axes 2')
axes[1,0].plot(np.random.rand(5))
axes[1,0].set_title('axes 3')
axes[1,1].plot(np.random.rand(5))
axes[1,1].set_title('axes 4')

plt.tight_layout()
plt.show()

# %% [markdown]
# Axes와 Axis는 다른 객체이다.
# Axis는 ticks와 tick labels을 제공하며 이는 Axes의 데이터 범위에 대한 척도가 된다.

# %% [markdown]
# 하나의 Axes 객체는 두 개 이상의 Axis 객체를 가진다.
# Axis 객체는 플롯의 가로축이나 세로축을 나타내는 객체이다
#
# twinx 명령으로 대해 복수의 y축을 가진 플롯을 만들 수 있다.
# twinx 명령은 x축을 공유하는 새로운 Axes 객체를 만듭니다.

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title('2개의 y축 한 figure에서 사용하기')
ax0.plot([10,5,2,9,7], 'r-', label='y0')
ax0.set_ylabel('y0')
ax0.grid(False)
ax1.plot([100,200,220,180,120], 'g:', label='y1')
ax1.set_ylabel('y1')
ax1.grid(False)
ax0.set_xlabel('공유되는 x축')
plt.show()

# %% [markdown]
# # 바 차트

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

y = [2,3,1]
x = ['가','나','다']
plt.title('Bar Chart')
plt.bar(x,y)
plt.xlabel('가나다')
plt.ylabel('빈도 수')
plt.show()

# %%
# bar 마다 색상 적용

# %%
y = [2,3,1]
x = ['가','나','다']
colors = ['red','green','blue']
plt.title('Bar Chart')
plt.bar(x,y,color=colors)
plt.xlabel('가나다')
plt.ylabel('빈도 수')
plt.show()

# %% [markdown]
# #### xerr 인수나 yerr 인수를 지정하면 에러 바를 추가할 수 있다.
# #### alpha는 투명도를 지정한다. 0이면 완전 투명, 1이면 완전 불투명

# %%
np.random.seed(0)

people = ['몽룡','춘향','방자','향단']
performance = 3+10 * np.random.rand(len(people))
error = np.random.rand(len(people))

plt.title('Barh Chart')
plt.barh(people, performance, xerr=error, alpha=0.4)
plt.xlabel('x 라벨')
plt.show()

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
q = titanic.survived.value_counts()
x = ['사망자','생존자']
y = q

bar_color = ['red','green']
plt.title('타이타닉호 생존 여부')
plt.barh(x,y, color=bar_color)
plt.xlabel('인원 수')
plt.show()

# %%
labels = ['월세','전세','자가','기타']
sizes = [15,30,45,10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0,0,0.1,0)
plt.title('Pie Chart')
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.show()

# %%
titanic.age.value_counts()
# bins = [0, 20, 30, 50, 70, 100]
# sizes = [33.8,32.2,25.8,5.3,0.7] 
# labels = ["미성년자", "청년", "장년", "중년", "노년"]
# explode = (0.1, 0, 0, 0, 0)
# colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "orange"]
# plt.pie(sizes, explode=explode, labels=labels, colors=colors,
#         autopct='%1.1f%%', shadow=True, startangle=90)
# plt.axis('equal')
# plt.show()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: age, Length: 88, dtype: int64

# %%
titanic_age = titanic[titanic['age'].notnull()]['age']

# %% [markdown]
# #### 히스토그램을 그리기 위한 hist 명령도 있다.
# #### hist 명령은 bins 인수로 데이터를 집계할 구간 정보를 받는다.
# #### 반환값으로 데이터 집계 결과를 반환한다.

# %%
np.random.seed(0)
x = np.random.randn(1000)
plt.title('Histogram')
arrays, bins, patches = plt.hist(x, bins=10)
plt.show()

# %%
arrays
# Out:
# array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.])

# %%
bins
# Out:
# array([-3.04614305, -2.46559324, -1.88504342, -1.3044936 , -0.72394379,
#        -0.14339397,  0.43715585,  1.01770566,  1.59825548,  2.1788053 ,
#         2.75935511])

# %% [markdown]
# 스캐터 플롯

# %%
np.random.seed(0)
X = np.random.normal(0,1,100)
Y = np.random.normal(0,1,100)
plt.title('Scatter Plot')
plt.scatter(X,Y)
plt.show()

# %%
N=30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N))**2
plt.title('Bubble Chart')
plt.scatter(x, y1, c=y2, s=y3)
plt.show()

# %% [markdown]
# imshow : 화상 데이터처럼 행과 열을 가진 행렬 형태의 2차원 데이터를 2차원 자료의 크기를 색깔로 표시하는 것이다.

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[0]
X
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.title('mnist digits; 0')
plt.imshow(X, interpolation='nearest', cmap=plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left=0.35, right=0.65, bottom=0.35, top=0.65)
plt.show()

# %%
dir(plt.cm)[:10]  # 일부 칼라맵을 표시해준다.
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r']

# %%
fig, axes = plt.subplots(1, 4, figsize = (12, 3),
                         subplot_kw = {'xticks' : [], 'yticks' : []})
axes[0].set_title('plt.cm.Blues')
axes[0].imshow(X, interpolation = 'nearest', cmap = plt.cm.Blues)
axes[1].set_title('plt.cm.Blues_r')
axes[1].imshow(X, interpolation = 'nearest', cmap = plt.cm.Blues_r)
axes[2].set_title('plt.BrBG')
axes[2].imshow(X, interpolation = 'nearest', cmap = 'BrBG')
axes[3].set_title('plt.BrBG_r')
axes[3].imshow(X, interpolation = 'nearest', cmap = 'BrBG_r')
plt.show()

# %%
methods = {
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36',
    'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian',
    'bessel', 'mitchell', 'sinc', 'lanczos'
}
fig, axes = plt.subplots(3, 6, figsize = (12, 6),
                         subplot_kw = {'xticks' : [], 'yticks' : []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap = plt.cm.bone_r, interpolation = interp_method)
    ax.set_title(interp_method)
    
plt.show()

# %%
def f(x,y):
    return (1-x / 2 +x ** 5 + y **3) * np.exp(-x ** 2 - y **2)

n=256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
XX,YY = np.meshgrid(x,y)
ZZ = f(XX, YY)

plt.title('Contour plots')
plt.contourf(XX,YY,ZZ, alpha=.75,cmap='jet')
plt.contour(XX,YY,ZZ, colors='black')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
XX, YY = np.meshgrid(X, Y)
RR = np.sqrt(XX**2 + YY**2)
ZZ = np.sin(RR)
fig = plt.figure()
ax = Axes3D(fig)
ax.set_title("3D Surface Plot")
ax.plot_surface(XX, YY, ZZ, rstride = 1, cstride = 1, cmap = 'hot')
plt.show()
# Out:
# C:\Users\jaehee\AppData\Local\Temp\ipykernel_9804\2020736620.py:8: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
