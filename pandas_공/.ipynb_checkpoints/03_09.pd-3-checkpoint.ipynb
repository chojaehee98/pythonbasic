# %%
# at, iat : 단일 값 검색에 최적화된 것
at은 행, 열의 label로 인덱싱한다. iat은 행, 열의 인덱스(정수)로 인덱싱한다

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
nba = pd.read_csv("datas/nba.csv", index_col = "Name")
nba.nlargest(1, columns = ["Salary"])
# Out:
#                                 Team Position Birthday    Salary
# Name
# Stephen Curry  Golden State Warriors       PG  3/14/88  40231758

# %%
# %%timeit은 jupyter 매직 메서드입니다 : 코드를 실행하고 걸리는 평균시간을 측정한다.
# %%timeit
nba.at["Stephen Curry","Birthday"]
# Out:
# 8.7 µs ± 380 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
nba.loc["Stephen Curry","Birthday"]
# Out:
# 11.8 µs ± 807 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
nba.iat[263,1]
# Out:
# 19.1 µs ± 355 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
nba.iloc[263,1]
# Out:
# 52.8 µs ± 15 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
#Series에서도 사용 가능 : index 값을 활용해서 인덱싱합니다.

# %%
nba.Salary.loc["Damian Lillard"]
# Out:
# 29802321

# %%
nba.columns
# Out:
# Index(['Team', 'Position', 'Birthday', 'Salary'], dtype='object')

# %%
nba.columns=['Team', 'Position','Date of Birth','Pay']

# %%
nba.head(1)
# Out:
#                             Team Position Date of Birth      Pay
# Name
# Shake Milton  Philadelphia 76ers       SG       9/26/96  1445697

# %%
nba.rename(columns={"Date of Birth":"Birthday",
                    "Pay":"Salary"})
# Out:
#                                Team Position  Birthday    Salary
# Name
# Shake Milton     Philadelphia 76ers       SG   9/26/96   1445697
# Christian Wood      Detroit Pistons       PF   9/27/95   1645357
# PJ Washington     Charlotte Hornets       PF   8/23/98   3831840
# Derrick Rose        Detroit Pistons       PG   10/4/88   7317074
# Marial Shayok    Philadelphia 76ers        G   7/26/95     79568
# ...                             ...      ...       ...       ...
# Austin Rivers       Houston Rockets       PG    8/1/92   2174310
# Harry Giles        Sacramento Kings       PF   4/22/98   2578800
# Robin Lopez         Milwaukee Bucks        C    4/1/88   4767000
# Collin Sexton   Cleveland Cavaliers       PG    1/4/99   4764960
# Ricky Rubio            Phoenix Suns       PG  10/21/90  16200000
#
# [450 rows x 4 columns]

# %%
nba.loc["Giannis Antetokounmpo"]
# Out:
# Team             Milwaukee Bucks
# Position                      PF
# Date of Birth            12/6/94
# Pay                     25842697
# Name: Giannis Antetokounmpo, dtype: object

# %%
nba = nba.rename(index = {"Giannis Antetokounmpo":"Greek Freak"})

# %%
nba.loc["Greek Freak"]
# Out:
# Team             Milwaukee Bucks
# Position                      PF
# Date of Birth            12/6/94
# Pay                     25842697
# Name: Greek Freak, dtype: object

# %%
NFL=pd.read_csv('datas/nfl.csv', index_col='Name',
           parse_dates=['Birthday'])
NFL
# Out:
#                                     Team Position   Birthday   Salary
# Name
# Tremon Smith         Philadelphia Eagles       RB 1996-07-20   570000
# Shawn Williams        Cincinnati Bengals       SS 1991-05-13  3500000
# Adam Butler         New England Patriots       DT 1994-04-12   645000
# Derek Wolfe               Denver Broncos       DE 1990-02-24  8000000
# Jake Ryan           Jacksonville Jaguars      OLB 1992-02-27  1000000
# ...                                  ...      ...        ...      ...
# Bashaud Breeland      Kansas City Chiefs       CB 1992-01-30   805000
# Craig James          Philadelphia Eagles       CB 1996-04-29   570000
# Jonotthan Harrison         New York Jets        C 1991-08-25  1500000
# Chuma Edoga                New York Jets       OT 1997-05-25   495000
# Tajae Sharpe            Tennessee Titans       WR 1994-12-23  2025000
#
# [1655 rows x 4 columns]

# %%
NFL['Team'].value_counts()
# Out:
# New York Jets           58
# Kansas City Chiefs      56
# Washington Redskins     56
# New Orleans Saints      55
# San Francisco 49Ers     55
# Denver Broncos          54
# Minnesota Vikings       54
# Los Angeles Chargers    54
# Seattle Seahawks        53
# Dallas Cowboys          53
# Buffalo Bills           53
# Atlanta Falcons         53
# Detroit Lions           53
# Chicago Bears           53
# Los Angeles Rams        52
# New York Giants         52
# Philadelphia Eagles     52
# Houston Texans          52
# Arizona Cardinals       51
# Cincinnati Bengals      51
# Green Bay Packers       51
# Oakland Raiders         51
# Jacksonville Jaguars    50
# Cleveland Browns        49
# Miami Dolphins          49
# Indianapolis Colts      49
# Carolina Panthers       49
# New England Patriots    49
# Baltimore Ravens        48
# Pittsburgh Steelers     47
# Tampa Bay Buccaneers    47
# Tennessee Titans        46
# Name: Team, dtype: int64

# %%
NFL.nlargest(5, columns=['Salary'])
# Out:
#                                  Team Position   Birthday    Salary
# Name
# Kirk Cousins        Minnesota Vikings       QB 1988-08-19  27500000
# Marcus Mariota       Tennessee Titans       QB 1993-10-30  20922000
# Jameis Winston   Tampa Bay Buccaneers       QB 1994-01-06  20922000
# Derek Carr            Oakland Raiders       QB 1991-03-28  19900000
# Jimmy Garoppolo   San Francisco 49Ers       QB 1991-11-02  17200000

# %%
NFL.sort_values(by=['Team','Salary'],ascending=[True,False])
# Out:
#                                    Team Position   Birthday    Salary
# Name
# Chandler Jones        Arizona Cardinals      OLB 1990-02-27  16500000
# Patrick Peterson      Arizona Cardinals       CB 1990-07-11  11000000
# Larry Fitzgerald      Arizona Cardinals       WR 1983-08-31  11000000
# David Johnson         Arizona Cardinals       RB 1991-12-16   5700000
# Justin Pugh           Arizona Cardinals        G 1990-08-15   5000000
# ...                                 ...      ...        ...       ...
# Ross Pierschbacher  Washington Redskins        C 1995-05-05    495000
# Kelvin Harmon       Washington Redskins       WR 1996-12-15    495000
# Wes Martin          Washington Redskins        G 1996-05-09    495000
# Jimmy Moreland      Washington Redskins       CB 1995-08-26    495000
# Jeremy Reaves       Washington Redskins       SS 1996-08-29    495000
#
# [1655 rows x 4 columns]

# %%
# Series apply()메서드
# 각 값에 대해 모든 함수를 적용하는 방법
# 첫 인자 값은 함수 객체(소괄호 없이)를 넘겨주며 필수값입니다.

# %%
Series.apply(객체, convert_dtype    )

# %%
Pokemons = pd.read_csv("datas/pokemon.csv", index_col="Pokemon").squeeze("columns")
Pokemons
# Out:
# Pokemon
# Bulbasaur      Grass / Poison
# Ivysaur        Grass / Poison
# Venusaur       Grass / Poison
# Charmander               Fire
# Charmeleon               Fire
#                     ...
# Stakataka        Rock / Steel
# Blacephalon      Fire / Ghost
# Zeraora              Electric
# Meltan                  Steel
# Melmetal                Steel
# Name: Type, Length: 809, dtype: object

# %%
# 타입 값이 2개면 "Multi"라는 값을 반환,
# 타입이 1개면 "Single"이라 반환한다.

# %%
def single_or_multi(type):
    if "/" in type:          # /를 기준으로 타입이
        return "Multi"
    return "Single"

# %%
Pokemons.apply(single_or_multi)
# Out:
# Pokemon
# Bulbasaur       Multi
# Ivysaur         Multi
# Venusaur        Multi
# Charmander     Single
# Charmeleon     Single
#                 ...
# Stakataka       Multi
# Blacephalon     Multi
# Zeraora        Single
# Meltan         Single
# Melmetal       Single
# Name: Type, Length: 809, dtype: object

# %%
Pokemons.apply(single_or_multi).value_counts()
# Out:
# Multi     405
# Single    404
# Name: Type, dtype: int64

# %%
df=pd.DataFrame([[4,9]]*3, columns=["A","B"])
df
# Out:
#    A  B
# 0  4  9
# 1  4  9
# 2  4  9

# %%
df.apply(np.sqrt)  # sqrt 제곱근을 구해주는 함수
# Out:
#      A    B
# 0  2.0  3.0
# 1  2.0  3.0
# 2  2.0  3.0

# %%
np.sqrt(df) # 위랑 똑같
# Out:
#      A    B
# 0  2.0  3.0
# 1  2.0  3.0
# 2  2.0  3.0

# %%
# 차원 축소 함수인 sum을 활용  axis =0 은 행

df.apply(np.sum, axis=0)   # 0, 'index', 'rows' 똑같
# Out:
# A    12
# B    27
# dtype: int64

# %%
df.apply(lambda x: [1,2], axis=0)
# Out:
#    A  B
# 0  1  1
# 1  2  2

# %%
df.apply(lambda x: [1,2], axis=1)
# Out:
# 0    [1, 2]
# 1    [1, 2]
# 2    [1, 2]
# dtype: object

# %%
# result_type='expand' 와 axis=1을 동시에 하면 DataFrame의 결과를 얻을 수 있다

# %%
df.apply(lambda x: [1,2],axis=1,result_type='expand')
# Out:
#    0  1
# 0  1  2
# 1  1  2
# 2  1  2

# %%
df.apply(lambda x: pd.Series([1,2], index=['foo','bar']),axis=1)
# Out:
#    foo  bar
# 0    1    2
# 1    1    2
# 2    1    2

# %%
df.apply(lambda x: [1,2], axis=1, result_type='broadcast')
# Out:
#    A  B
# 0  1  2
# 1  1  2
# 2  1  2

# %%
df3 = pd.DataFrame({
    'A' : [1,3,4,3,4],
    'B' : [2,3,1,2,3],
    'C' : [1,5,2,4,4]
})
df3
# Out:
#    A  B  C
# 0  1  2  1
# 1  3  3  5
# 2  4  1  2
# 3  3  2  4
# 4  4  3  4

# %%
df3.apply(lambda x: x.max() - x.min())
# Out:
# A    3
# B    2
# C    4
# dtype: int64

# %%
df3.apply(pd.value_counts)
# Out:
#      A    B    C
# 1  1.0  1.0  1.0
# 2  NaN  2.0  1.0
# 3  2.0  2.0  NaN
# 4  2.0  NaN  2.0
# 5  NaN  NaN  1.0

# %%
import seaborn as sns
titanic=sns.load_dataset("titanic")

# %%
titanic["adult/child"] = titanic.apply(lambda r: "adult" if r.age >=20 else "child", axis=1)
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone adult/child
# 886    man        True  NaN  Southampton    no   True       adult
# 887  woman       False    B  Southampton   yes   True       child
# 888  woman       False  NaN  Southampton    no  False       child
# 889    man        True    C    Cherbourg   yes   True       adult
# 890    man        True  NaN   Queenstown    no   True       adult

# %%
titanic["category1"] = titanic.apply(lambda r: r['sex'] if r.age >= 20 else "child", axis=1)
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone adult/child category1
# 886    man        True  NaN  Southampton    no   True       adult      male
# 887  woman       False    B  Southampton   yes   True       child     child
# 888  woman       False  NaN  Southampton    no  False       child     child
# 889    man        True    C    Cherbourg   yes   True       adult      male
# 890    man        True  NaN   Queenstown    no   True       adult      male

# %%
# fillna() 메서드 : NaN 값을 원하는 값으로 바꿀 수 있다.
pd.DataFrame.fillna(value=None, *,)

# %%
df = pd.DataFrame([[np.nan, 2, np.nan, 0],
                   [3, 4, np.nan, 1],
                   [np.nan, np.nan, np.nan, np.nan],
                   [np.nan, 3, np.nan, 4]],
                  columns = list("ABCD"))
df
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  3.0 NaN  4.0

# %%
df.fillna(0)
# Out:
#      A    B    C    D
# 0  0.0  2.0  0.0  0.0
# 1  3.0  4.0  0.0  1.0
# 2  0.0  0.0  0.0  0.0
# 3  0.0  3.0  0.0  4.0

# %%
values = {"A":0,"B":1,"C":2,"D":3}
df.fillna(value=values)
# Out:
#      A    B    C    D
# 0  0.0  2.0  2.0  0.0
# 1  3.0  4.0  2.0  1.0
# 2  0.0  1.0  2.0  3.0
# 3  0.0  3.0  2.0  4.0

# %%
values = {"A":0,"B":1,"C":2,"D":3}
df.fillna(value=values, limit =1)  # limit 키워드 인자에 숫자를 전달하여 그 숫자만큼 콜럼마다 변경 획수 제한
# Out:
#      A    B    C    D
# 0  0.0  2.0  2.0  0.0
# 1  3.0  4.0  NaN  1.0
# 2  NaN  1.0  NaN  3.0
# 3  NaN  3.0  NaN  4.0

# %%
df
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  3.0 NaN  4.0

# %%
df2= pd.DataFrame(np.zeros((3,4)),columns=list("ABCE"))
df.fillna(df2)
# Out:
#      A    B    C    D
# 0  0.0  2.0  0.0  0.0
# 1  3.0  4.0  0.0  1.0
# 2  0.0  0.0  0.0  NaN
# 3  NaN  3.0  NaN  4.0

# %%
titanic.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# adult/child    891
# category1      891
# dtype: int64

# %%
titanic[titanic['age'].isna()]# isnull()==isna()
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 5           0       3    male  NaN      0      0   8.4583        Q   Third
# 17          1       2    male  NaN      0      0  13.0000        S  Second
# 19          1       3  female  NaN      0      0   7.2250        C   Third
# 26          0       3    male  NaN      0      0   7.2250        C   Third
# 28          1       3  female  NaN      0      0   7.8792        Q   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 859         0       3    male  NaN      0      0   7.2292        C   Third
# 863         0       3  female  NaN      8      2  69.5500        S   Third
# 868         0       3    male  NaN      0      0   9.5000        S   Third
# 878         0       3    male  NaN      0      0   7.8958        S   Third
# 888         0       3  female  NaN      1      2  23.4500        S   Third
#
# ...

# %%
a = round(titanic['age'].mean(),1)
titanic['age']=titanic['age'].fillna(a)
titanic
# titanic['age'] =titanic['age'].fillna(round(titanic['age'].mean(),1))
# titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  29.7      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
index_age_is_nan = titanic[titanic['age'].isna()].index
print(index_age_is_nan)
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
titanic.fillna({'age': round(titanic['age'].mean(),1)},inplace=True)
titanic.iloc[index_age_is_nan]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 5           0       3    male  29.7      0      0   8.4583        Q   Third
# 17          1       2    male  29.7      0      0  13.0000        S  Second
# 19          1       3  female  29.7      0      0   7.2250        C   Third
# 26          0       3    male  29.7      0      0   7.2250        C   Third
# 28          1       3  female  29.7      0      0   7.8792        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 859         0       3    male  29.7      0      0   7.2292        C   Third
# 863         0       3  female  29.7      8      2  69.5500        S   Third
# 868         0       3    male  29.7      0      0   9.5000        S   Third
# 878         0       3    male  29.7      0      0   7.8958        S   Third
# 888         0       3  female  29.7      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
d = {'coll' : [1,2], 'cpl2': [3,4]}
df = pd.DataFrame(data=d)
df.dtypes
# Out:
# coll    int64
# cpl2    int64
# dtype: object

# %%
df.astype({'coll':'int32'}).dtypes
# Out:
# coll    int32
# cpl2    int64
# dtype: object

# %%
e = pd.read_csv('datas/employees.csv', parse_dates=['Start Date'])
e
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06       NaN   True     Marketing
# 1        Thomas    Male 1996-03-31   61933.0   True           NaN
# 2         Maria  Female        NaT  130590.0  False       Finance
# 3         Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4         Larry    Male 1998-01-24  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male 1984-01-31   42392.0  False       Finance
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.0   True         Sales
# 1000        NaN     NaN        NaT       NaN    NaN           NaN
#
# [1001 rows x 6 columns]

# %%
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      999 non-null    float64
#  4   Mgmt        933 non-null    object
#  5   Team        957 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 47.0+ KB

# %%
e['Mgmt']=e.Mgmt.astype('?')
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      999 non-null    float64
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    object
# dtypes: bool(1), datetime64[ns](1), float64(1), object(3)
# memory usage: 40.2+ KB

# %%
e.Salary=e.Salary.fillna(0)
sum((e.Salary - e.Salary.astype(int)) >0)
e['Salary']=e['Salary'].astype("i")
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      1001 non-null   int32
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    object
# dtypes: bool(1), datetime64[ns](1), int32(1), object(3)
# memory usage: 36.3+ KB

# %%
e.nunique()
e.Gender=e.Gender.astype('category')
e.Team=e.Team.astype('category')
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      1001 non-null   int32
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](1), int32(1), object(1)
# memory usage: 23.1+ KB

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  29.7      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic['category2']=titanic.sex + titanic.age.astype(str)

# %%
titanic[['age','category2']]
# Out:
#       age   category2
# 0    22.0    male22.0
# 1    38.0  female38.0
# 2    26.0  female26.0
# 3    35.0  female35.0
# 4    35.0    male35.0
# ..    ...         ...
# 886  27.0    male27.0
# 887  19.0  female19.0
# 888  29.7  female29.7
# 889  26.0    male26.0
# 890  32.0    male32.0
#
# [891 rows x 2 columns]

# %%
# 실수 값을 카테고리 값으로 변환

# %%
cut : 하한값, 상한값을 갖는 리스트를 bins 키워드 인수에 전달
qcut:

# %%
ages = [0,2,10,21,23,37,31,61,20,41,32,101]
bins = [1,20,30,50,70,100]
labels = ["미성년자","청년","장년","중년","노년"]
cats = pd.cut(ages, bins, labels=labels)
cats
# Out:
# [NaN, '미성년자', '미성년자', '청년', '청년', ..., '중년', '미성년자', '장년', '장년', NaN]
# Length: 12
# Categories (5, object): ['미성년자' < '청년' < '장년' < '중년' < '노년']

# %%
type(cats)
# Out:
# pandas.core.arrays.categorical.Categorical

# %%
cats.categories
# Out:
# Index(['미성년자', '청년', '장년', '중년', '노년'], dtype='object')

# %%
cats.codes
# Out:
# array([-1,  0,  0,  1,  1,  2,  2,  3,  0,  2,  2, -1], dtype=int8)

# %%
df4 = pd.DataFrame(ages, columns=['ages'])
df4["age_cat"]= pd.cut(df4.ages,bins, labels=labels)
df4
# Out:
#     ages age_cat
# 0      0     NaN
# 1      2    미성년자
# 2     10    미성년자
# 3     21      청년
# 4     23      청년
# 5     37      장년
# 6     31      장년
# 7     61      중년
# 8     20    미성년자
# 9     41      장년
# 10    32      장년
# 11   101     NaN

# %%
df4.dtypes
# Out:
# ages          int64
# age_cat    category
# dtype: object

# %%
df4["age_cat"].astype(str) + df4["ages"].astype(str)
# Out:
# 0       nan0
# 1      미성년자2
# 2     미성년자10
# 3       청년21
# 4       청년23
# 5       장년37
# 6       장년31
# 7       중년61
# 8     미성년자20
# 9       장년41
# 10      장년32
# 11    nan101
# dtype: object

# %%
# qcut()

data = np.random.randn(1000)
cats = pd.qcut(data, 4, labels=["Q1","Q2","Q3","Q4"])
cats
# Out:
# ['Q3', 'Q3', 'Q2', 'Q4', 'Q1', ..., 'Q2', 'Q2', 'Q3', 'Q1', 'Q2']
# Length: 1000
# Categories (4, object): ['Q1' < 'Q2' < 'Q3' < 'Q4']

# %%
pd.value_counts(cats)
# Out:
# Q1    250
# Q2    250
# Q3    250
# Q4    250
# dtype: int64

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  29.7      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
titanic['age'].fillna(titanic['a]
bins = [1, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "장년", "중년", "노년"]
cats = pd.cut(ages, bins, labels=labels)
cats
# Out:
# 0        청년
# 1        장년
# 2        청년
# 3        장년
# 4        장년
#        ...
# 886      청년
# 887    미성년자
# 888      청년
# 889      청년
# 890      장년
# Name: age, Length: 891, dtype: category
# Categories (5, object): ['미성년자' < '청년' < '장년' < '중년' < '노년']

# %%
titanic1=pd.DataFrame(titanic['age'], columns=['ages'])

titanic1["ages_cat"]= pd.cut(titanic1,bins,labels=labels)
titanic1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2040\2028503135.py in <module>
#       1 titanic1=pd.DataFrame(titanic['age'], columns=['ages'])
#       2
# ----> 3 titanic1["ages_cat"]= pd.cut(titanic1,bins,labels=labels)
#       4 titanic1
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     239
#     240     original = x
# --> 241     x = _preprocess_for_cut(x)
#     242     x, dtype = _coerce_to_type(x)
#     243
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _preprocess_for_cut(x)
#     599         x = np.asarray(x)
#     600     if x.ndim != 1:
# --> 601         raise ValueError("Input array must be 1 dimensional")
#     602
#     603     return x
#
# ValueError: Input array must be 1 dimensional

# %%
titanic.value_counts(moralize=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2040\3326844734.py in <module>
# ----> 1 titanic.value_counts(moralize=True)
#
# TypeError: value_counts() got an unexpected keyword argument 'moralize'

# %%
import pandas as pd
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic['age'].fillna(titanic['age'].mean(), inplace=True)
bins = [1, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "장년", "중년", "노년"]
titanic["연령층"] = pd.cut(titanic["age"],bins, labels=labels)

titanic['category3']= titanic.apply(lambda i: "미성년자" if i['age'] < 20 else i['연령층'] + ('남성' if i['sex'] == 'male' else '여성'),axis=1)
titanic[['연령층','age','sex','category3']]
# Out:
#       연령층        age     sex category3
# 0      청년  22.000000    male      청년남성
# 1      장년  38.000000  female      장년여성
# 2      청년  26.000000  female      청년여성
# 3      장년  35.000000  female      장년여성
# 4      장년  35.000000    male      장년남성
# ..    ...        ...     ...       ...
# 886    청년  27.000000    male      청년남성
# 887  미성년자  19.000000  female      미성년자
# 888    청년  29.699118  female      청년여성
# 889    청년  26.000000    male      청년남성
# 890    장년  32.000000    male      장년남성
#
# [891 rows x 4 columns]

# %%
titanic[(titanic["age"]<1) | (titanic["age"] > 100)][['연령층','age','sex','category3']]
# Out:
#      연령층   age     sex category3
# 78   NaN  0.83    male      미성년자
# 305  NaN  0.92    male      미성년자
# 469  NaN  0.75  female      미성년자
# 644  NaN  0.75  female      미성년자
# 755  NaN  0.67    male      미성년자
# 803  NaN  0.42    male      미성년자
# 831  NaN  0.83    male      미성년자
