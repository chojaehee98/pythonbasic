# %%
import pandas as pd

# %%
# %cd c:\\python
# Out:
# c:\python

# %%
store = pd.read_csv('data',index_col = 0, encoding='CP949', low_memory=False)

# %%
store
# Out:
#            상호명 업종명(종목명)                   소재지도로명주소  \
# 시군명
# 고양시  별미냉면(신원점)     일반한식         경기도 고양시 덕양구 신원로 10
# 고양시       맘스터치     서양음식        경기도 고양시 덕양구 충장로 134
# 고양시   경희원도태권스쿨   예체능계학원       경기도 고양시 일산동구 강송로 115
# 고양시      이내과의원       의원     경기도 고양시 일산동구 숲속마을1로 73
# 고양시       전의명가     일반한식    경기도 고양시 일산서구 일중로15번길 82
# ..         ...      ...                        ...
# 김포시     더쉐프팩토리     일반한식  경기도 김포시 양촌읍 김포한강4로 341-12
# 김포시  빈센트 미술교습소   예체능계학원        경기도 김포시 사우중로74번길 29
# 김포시  빌리어드 당구클럽      당구장                        NaN
# 성남시      북경성반점     음식점업         경기도 성남시 수정구 복정로 92
# 성남시     섬마을고깃간      소매업        경기도 성남시 중원구 도촌남로 33
#
#                                      소재지지번주소     우편번호         위도          경도  \
# 시군명
# 고양시       경기도 고양시 덕양구 신원동 633번지 1층 101호 102호  10571.0  37.661855  126.890313
# 고양시       경기도 고양시 덕양구 행신동 943-1번지 아이프라자 114호  10495.0  37.624376  126.834956
# 고양시     경기도 고양시 일산동구 백석동 1225번지 중앙프라자상가 405호  10420.0  37.649266  126.786375
# ...

# %%
a = store[store['휴폐업 정보'] == '계속사업자']

# %%
a
# Out:
#               상호명 업종명(종목명)                   소재지도로명주소  \
# 시군명
# 고양시     별미냉면(신원점)     일반한식         경기도 고양시 덕양구 신원로 10
# 고양시          맘스터치     서양음식        경기도 고양시 덕양구 충장로 134
# 고양시         이내과의원       의원     경기도 고양시 일산동구 숲속마을1로 73
# 고양시          전의명가     일반한식    경기도 고양시 일산서구 일중로15번길 82
# 고양시  치킨플러스(고양원흥점)       스넥        경기도 고양시 덕양구 의장로 122
# ..            ...      ...                        ...
# 김포시      신안홍어 꽈배기   기타음료식품      경기도 김포시 김포한강1로51번길 46
# 성남시      베이키 베이커리     음식점업    경기도 성남시 분당구 미금일로74번길 20
# 김포시        더쉐프팩토리     일반한식  경기도 김포시 양촌읍 김포한강4로 341-12
# 김포시     빈센트 미술교습소   예체능계학원        경기도 김포시 사우중로74번길 29
# 김포시     빌리어드 당구클럽      당구장                        NaN
#
#                                     소재지지번주소     우편번호         위도          경도  \
# 시군명
# 고양시      경기도 고양시 덕양구 신원동 633번지 1층 101호 102호  10571.0  37.661855  126.890313
# 고양시      경기도 고양시 덕양구 행신동 943-1번지 아이프라자 114호  10495.0  37.624376  126.834956
# ...
