# %%
import pandas as pd

# %%
# %pwd
# Out:
# 'C:\\python\\project'

# %%
# %cd c:\\python
# Out:
# c:\python

# %%
x = pd.read_csv('datas/지역화폐발행및이용현황.csv',index_col = 0, encoding='CP949', low_memory=False)

# %%
x
# Out:
#         기준년월  월별카드발행수량(건)  월별카드충전액(천원)  월별카드사용액(천원)  월별모바일상품권이용등록자수(명)  \
# 시군명
# 가평군  2022-12        814.0    3600881.0    3996840.0                NaN
# 가평군  2022-11        701.0    4356413.0    3673972.0                NaN
# 가평군  2022-10        657.0    3205893.0    3586395.0                NaN
# 가평군  2022-09        832.0    4334836.0    3773560.0                NaN
# 가평군  2022-08        858.0    3091351.0    3600543.0                NaN
# ..       ...          ...          ...          ...                ...
# 화성시  2019-05      10661.0    4449088.0    1392631.0                NaN
# 화성시  2019-04       4826.0    1476982.0     204210.0                NaN
# 화성시  2019-03          NaN          NaN          NaN                NaN
# 화성시  2019-02          NaN          NaN          NaN                NaN
# 화성시  2019-01          NaN          NaN          NaN                NaN
#
#      월별모바일충전액(천원)  월별모바일사용액(천원)  월별지류상품권판매액(천원)  월별지류상품권회수액(천원)
# 시군명
# ...
