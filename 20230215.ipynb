# %%
a = (1,2,3)

# %%
b = [1,2,3]

# %%
b[0] = 10

# %%
b
# Out:
# [10, 2, 3]

# %%
def temp(variable_a):
    pass

# %%
# unpacking 
a , b  = (1, 2)

# %%
a, *b = [1,2,3,4]

# %%
b
# Out:
# [2, 3, 4]

# %%
for idx, x in enumerate(['a','b','c']):
    print(x)
# Out:
# a
# b
# c

# %%
# f(x) = ax + b 
# f(x) = 5x + 3
def func_a(x, a=5,b=3):
    return a*x + b

# %%
[func_a( x) for x in range(1,11)]
# Out:
# [8, 13, 18, 23, 28, 33, 38, 43, 48, 53]

# %%
import requests

# %%
payload = {"in_biz_cds":"0",
"in_scodes":"0",
"ins_lat":"37.566535",
"ins_lng":"126.9779692",
"search_text":"",
"p_sido_cd":"01",
"p_gugun_cd":"",
"in_distance":"0",
"in_biz_cd":"",
"isError":"true",
"searchType":"C",
"set_date":"",
"all_store":"0",
"T03":"0",
"T01":"0",
"T27":"0",
"T12":"0",
"T09":"0",
"T30":"0",
"T05":"0",
"T22":"0",
"T21":"0",
"T10":"0",
"T36":"0",
"T43":"0",
"T48":"0",
"P10":"0",
"P50":"0",
"P20":"0",
"P60":"0",
"P30":"0",
"P70":"0",
"P40":"0",
"P80":"0",
"whcroad_yn":"0",
"P90":"0",
"new_bool":"0",
"iend":"1000",
"rndCod":"CZVMPDMCTR",}

# %%
r = requests.post(url, data={"in_biz_cds":"0",
"in_scodes":"0",
"ins_lat":"37.566535",
"ins_lng":"126.9779692",
"search_text":"",
"p_sido_cd":"01",
"p_gugun_cd":"",
"in_distance":"0",
"in_biz_cd":"",
"isError":"true",
"searchType":"C",
"set_date":"",
"all_store":"0",
"T03":"0",
"T01":"0",
"T27":"0",
"T12":"0",
"T09":"0",
"T30":"0",
"T05":"0",
"T22":"0",
"T21":"0",
"T10":"0",
"T36":"0",
"T43":"0",
"T48":"0",
"P10":"0",
"P50":"0",
"P20":"0",
"P60":"0",
"P30":"0",
"P70":"0",
"P40":"0",
"P80":"0",
"whcroad_yn":"0",
"P90":"0",
"new_bool":"0",
"iend":"1000",
"rndCod":"CZVMPDMCTR",})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16552\683005735.py in <module>
# ----> 1 r = requests.post(url, data={"in_biz_cds":"0",
#       2 "in_scodes":"0",
#       3 "ins_lat":"37.566535",
#       4 "ins_lng":"126.9779692",
#       5 "search_text":"",
#
# NameError: name 'url' is not defined

# %%
r.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16552\661903446.py in <module>
# ----> 1 r.json()
#
# NameError: name 'r' is not defined

# %%
url = "https://www.starbucks.co.kr/store/getStore.do?r=PO47G07Y8Y"

# %%
payload['p_sido_cd'] = '05'
r = requests.post(url, data=payload)

# %%
r.json()['list']
# Out:
# [{'seq': 0,
#   'sido_cd': None,
#   'sido_nm': None,
#   'gugun_cd': None,
#   'gugun_nm': None,
#   'code_order': None,
#   'view_yn': None,
#   'store_num': None,
#   'sido': None,
#   'gugun': None,
#   'address': None,
#   'new_img_nm': None,
#   'p_pro_seq': 0,
#   'p_view_yn': None,
#   'p_sido_cd': '',
#   'p_gugun_cd': '',
#   'p_store_nm': None,
#   'p_theme_cd': None,
#   'p_wireless_yn': None,
#   'p_smoking_yn': None,
#   'p_book_yn': None,
#   'p_music_yn': None,
#   'p_terrace_yn': None,
#   'p_table_yn': None,
#   'p_takeout_yn': None,
#   'p_parking_yn': None,
#   'p_dollar_assent': None,
#   'p_card_recharge': None,
#   'p_subway_yn': None,
#   'stb_store_file_renew': None,
#   'stb_store_theme_renew': None,
#   'stb_store_time_renew': None,
#   'stb_store_lsm': None,
#   's_code': '1605',
#   's_name': '금정남산동DT',
#   'tel': '1522-3232',
#   'fax': '051-582-3706',
#   'sido_code': '05',
#   'sido_name': '부산',
#   'gugun_code': '0501',
#   'gugun_name': '금정구',
# ...

# %%
url_sido = "https://www.starbucks.co.kr/store/getSidoList.do"
r2 = requests.post(url_sido, data={'rndCod': 'VH3P0RO6DH'})
total = []
for data in r2.json()['list']:
    payload['p_sido_cd'] = data['sido_cd']
    r = requests.post(url, data=payload)
    total += r.json()['list']
    print(data['sido_cd'], data['sido_nm'])
# Out:
# 01 서울
# 08 경기
# 02 광주
# 03 대구
# 04 대전
# 05 부산
# 06 울산
# 07 인천
# 09 강원
# 10 경남
# 11 경북
# 12 전남
# 13 전북
# 14 충남
# 15 충북
# 16 제주
# 17 세종

# %%
store = {x['s_name'] : x['open_dt'] for x in total}

# %%
sorted(store.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('인천관교DT', '20230309'),
#  ('계양구청', '20230307'),
#  ('김포마산역', '20230303'),
#  ('동래허심청', '20230228'),
#  ('대전문지', '20230224'),
#  ('다산이마트', '20230223'),
#  ('대천해수욕장', '20230223'),
#  ('광릉수목원', '20230222'),
#  ('용인한숲시티', '20230217'),
#  ('광주신창강변DT', '20230216'),
#  ('기장일광DT', '20230216'),
#  ('전주이마트', '20230216'),
#  ('새절역', '20230215'),
#  ('더북한산', '20230215'),
#  ('사상이마트', '20230209'),
#  ('아산탕정역', '20230209'),
#  ('경북도청대로', '20230202'),
#  ('분당현대R&D센터', '20230127'),
#  ('소사역', '20230120'),
#  ('고척아이파크', '20230119'),
#  ('울산 KTX', '20230119'),
#  ('광양마동DT', '20230118'),
#  ('의정부송산역DT', '20230113'),
#  ('대구대천', '20230112'),
#  ('울산주전비치', '20230112'),
#  ('제주노형로', '20230112'),
#  ('천안청당신도시', '20230106'),
#  ('전북남원DT', '20221222'),
#  ('전북김제DT', '20221221'),
#  ('경동1960', '20221216'),
#  ('대구금호', '20221215'),
#  ('울산일산비치DT', '20221215'),
#  ('창원사파', '20221215'),
#  ('충남홍성DT', '20221214'),
#  ('이대역', '20221213'),
#  ('신금호역', '20221213'),
#  ('파주가람', '20221213'),
# ...

# %%
sorted(map(int,['1', '11', '2','3']))

# %%
naver = "https://finance.naver.com/item/sise_day.naver?code=032640"

# %%
head = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36"}

# %%
r = requests.get(naver, headers=head)

# %%
pd.read_html(r.text)[0].dropna()

# %%
import pickle 
with open("./starbucks.pkl", "wb") as f:
    pickle.dump(total, f)

# %%
import pandas as pd

# %%
df = pd.read_csv("./data/상반기 주유소 판매가격.csv", encoding='euc-kr')

# %%
df2 = pd.concat([df for x in range(100)])

# %%
df2.to_csv("./data/oil_gas.csv", encoding='utf-8-sig')
