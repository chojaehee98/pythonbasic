# %%
import requests

# %%
url = 'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?_wadl&type=xml'
params ={'serviceKey' : 'AoRZmoHjg6WrWsDofPJs%2FC3AUCvP%2Bsga2pELyteZjCmwZK4Xq9Z%2Fu6BGQHuFq7qG4i2L22y83tLz%2FpqbxVlHkQ%3D%3D', 'pageNo' : '1', 'numOfRows' : '10', 'LAWD_CD' : '11110', 'DEAL_YMD' : '201512' }
response = requests.get(url, params=params)
response.status_code
# Out:
# 200

# %%
response.headers
# Out:
# {'Date': 'Mon, 13 Mar 2023 10:12:58 GMT', 'Server': 'apache', 'Content-Type': 'application/vnd.sun.wadl+xml', 'Set-Cookie': 'ROUTEID=.HTTP1; path=/', 'Keep-Alive': 'timeout=10, max=100', 'Connection': 'Keep-Alive', 'Transfer-Encoding': 'chunked'}

# %%
response.text
# Out:
# '<application xmlns="http://wadl.dev.java.net/2009/02" xmlns:xs="http://www.w3.org/2001/XMLSchema"><grammars><xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" attributeFormDefault="unqualified" elementFormDefault="unqualified">\r\n<xs:element name="GetRTMSDataSvcAptRentDevVO" type="getRTMSDataSvcAptRentDevVO"/>\r\n<xs:element name="GetRTMSDataSvcAptRentVO" type="getRTMSDataSvcAptRentVO"/>\r\n<xs:element name="GetRTMSDataSvcAptTradeDevVO" type="getRTMSDataSvcAptTradeDevVO"/>\r\n<xs:element name="GetRTMSDataSvcAptTradeVO" type="getRTMSDataSvcAptTradeVO"/>\r\n<xs:element name="GetRTMSDataSvcInduTradeVO" type="getRTMSDataSvcInduTradeVO"/>\r\n<xs:element name="GetRTMSDataSvcLandTradeVO" type="getRTMSDataSvcLandTradeVO"/>\r\n<xs:element name="GetRTMSDataSvcNrgTradeVO" type="getRTMSDataSvcNrgTradeVO"/>\r\n<xs:element name="GetRTMSDataSvcOffiRentDevVO" type="getRTMSDataSvcOffiRentDevVO"/>\r\n<xs:element name="GetRTMSDataSvcOffiRentVO" type="getRTMSDataSvcOffiRentVO"/>\r\n<xs:element nam
# ...

# %%
import xmltodict

# %%
apt = xmltodict.parse(response.text)
apt
# Out:
# {'application': {'@xmlns': 'http://wadl.dev.java.net/2009/02',
#   '@xmlns:xs': 'http://www.w3.org/2001/XMLSchema',
#   'grammars': {'xs:schema': {'@xmlns:xs': 'http://www.w3.org/2001/XMLSchema',
#     '@attributeFormDefault': 'unqualified',
#     '@elementFormDefault': 'unqualified',
#     'xs:element': [{'@name': 'GetRTMSDataSvcAptRentDevVO',
#       '@type': 'getRTMSDataSvcAptRentDevVO'},
#      {'@name': 'GetRTMSDataSvcAptRentVO', '@type': 'getRTMSDataSvcAptRentVO'},
#      {'@name': 'GetRTMSDataSvcAptTradeDevVO',
#       '@type': 'getRTMSDataSvcAptTradeDevVO'},
#      {'@name': 'GetRTMSDataSvcAptTradeVO',
#       '@type': 'getRTMSDataSvcAptTradeVO'},
#      {'@name': 'GetRTMSDataSvcInduTradeVO',
#       '@type': 'getRTMSDataSvcInduTradeVO'},
#      {'@name': 'GetRTMSDataSvcLandTradeVO',
#       '@type': 'getRTMSDataSvcLandTradeVO'},
#      {'@name': 'GetRTMSDataSvcNrgTradeVO',
#       '@type': 'getRTMSDataSvcNrgTradeVO'},
#      {'@name': 'GetRTMSDataSvcOffiRentDevVO',
# ...

# %%
import pandas as pd
apt1 = pd.DataFrame(apt)
apt1
# Out:
#                                                  application
# @xmlns                      http://wadl.dev.java.net/2009/02
# @xmlns:xs                   http://www.w3.org/2001/XMLSchema
# grammars   {'xs:schema': {'@xmlns:xs': 'http://www.w3.org...
# resources  {'@base': 'http://openapi.molit.go.kr/OpenAPI_...

# %%
import requests

from datetime import datetime
import time

def handle_rate_limits(response):
    now = datetime.now()
    reset_time = datetime.formtimestamp(int(response.headers['X-RateLimit_Reset']))
    remaining_requests = response.headers['X-Ratelimit-Remaining']
    remaining_time = (reset_time - now).total_seconds()
    intervals = remaining_time / (1.0 + int(remaining_requests))
    
    print('Sleepint for', intervals)
    time.sleep(intervals)
    time.sleep(intervals)
    return True
import xmltodict
import pandas as pd
for i in range(1,10):
    #time.sleep(2)
    response = requests.get('http://api.kcisa.kr/openapi/service/rest/meta/CHAheri',params={'serviceKey' : '451ac2f4-d15e-4925-b94d-1ae0af4c411c',"numOfRows":100,'pageNo':i})
    a = response.text
x = xmltodict.parse(str(a))['response']['body']['items']['item']    
p = pd.DataFrame(x)
p
# Out:
# <class '_io.TextIOWrapper'>
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4044\248588300.py in <module>
#      27 a = open("ddd.txt", "r")
#      28 print(type(a))
# ---> 29 x = xmltodict.parse(str(a))['response']['body']['items']['item']
#      30 p = pd.DataFrame(x)
#      31 p
#
# ~\anaconda3\lib\site-packages\xmltodict.py in parse(xml_input, encoding, expat, process_namespaces, namespace_separator, disable_entities, process_comments, **kwargs)
#     376         parser.Parse(b'',True)
#     377     else:
# --> 378         parser.Parse(xml_input, True)
#     379     return handler.item
#     380
#
# ExpatError: no element found: line 1, column 60
